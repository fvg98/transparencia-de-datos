# %% [markdown]
# # Datalab ITAM - Proyecto de Transparencia de Datos

# %% [markdown]
# **Objetivo:** extraer de datos de la [currícula y votaciones de la LXI legislatura](http://www.diputados.gob.mx/sistema_legislativo_LXI.html).
# <br><br> Como herramienta fundamental hacemos uso de la librería [`scrapy`](https://docs.scrapy.org/en/latest/)

# %% [markdown]
# Este proceso se divide en las siguientes secciones:
# 1. [Definición del Spider](#Definición-del-Spider)
# <br/><br/>
# 2. [Procesamiento de Datos](#Procesamiento-de-Datos)
#     * [Limpieza Perfil General](#Limpieza-Perfil-General)
#     * [Limpieza Proposiciones](#Limpieza-Proposiciones)
#     * [Limpieza Iniciativas](#Limpieza-Iniciativas)
#     * [Limpieza de la Ficha Curricular y las Comisiones](#Limpieza-de-la-Ficha-Curricular-y-las-Comisiones)
#     * [Limpieza Votaciones](#Limpieza-Votaciones)
# <br/><br/>
# 3. [Ejecución del Spider](#Ejecución-del-Spider)
# <br/><br/>
# 4. [Creación de la base de datos](#Creación-de-la-base-de-datos)
# <br/><br/>
# 5. [Visualizando los datos](#Visualizando-los-datos)

# %% [markdown]
# ### Identificación de tablas
# A continuación se presenta un caso ejemplo señalando cada una de las tablas a las que haremos referencia más adelante
#
# **Perfil general:** La primera tabla por cada diputado corresponde a la siguiente sección de la currícula
# <img src="Parte161.jpg" width="600">

# %% [markdown]
# **Iniciativas:** Podemos notar que, si bien tiene entradas con textos largos, no presenta una estructura muy compleja.
# <img src="ParteIniciativas61.jpg" width="600">

# %% [markdown]
# **Proposiciones:** Notamos que es muy similar a la tabla de iniciativas, a diferencia de que contiene una columna extra
# <img src="ParteProposiciones61.jpg" width="600">

# %% [markdown]
# **Ficha Curricular:** Para cada una de los apartados dentro de la ficha (Escolaridad, Administación Pública, Trayectoria Política, ...) se genera una lista de diccionarios por separado
# <img src="ParteEscolaridad61.jpg" width="600">

# %% [markdown]
# Tomando el [caso ejemplo](http://sitllxi.diputados.gob.mx/curricula.php?dipt=260), la información se guardará en el diccionario ***diccionario_final*** y abreviando las secciones de proposicones e iniciativas, la estructura dentro del archivo quedaría de la siguiente forma:
# ```css
# {
#     "cristabellzamoracabrera": {
#         "PERFIL GENERAL": [
#             {
#                 'ClaveUnica': 'cristabellzamoracabrera',
#                 'Nombre': 'Cristabell Zamora Cabrera',
#                 'TipoElección': 'Mayoría Relativa',
#                 'Entidad': 'Tamaulipas',
#                 'Partido': 'PRI',
#                 'Distrito': '1',
#                 'Curul': 'I-302',
#                 'Correo': 'cristabell.zamora@congreso.gob.mx ',
#                 'FechaNacimiento': '16-noviembre-1979',
#                 'Suplente': 'Adolfo Víctor García Jiménez',
#                 'UltimoGrado': 'Mayoría Relativa ',
#                 'PaginaInternet': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=260'
#             }
#         ],
#         "COMISIONES": [
#             {
#                 'Tipo': 'ORDINARIA',
#                 'Comisión': ' Fortalecimiento al Federalismo  '
#             },...
#         ],
#         "INICIATIVAS": [
#             {
#                 'NombreIniciativa': 'Proyecto de decreto que reforma el artículo 2 de la Ley del Impuesto al Valor Agregado.',
#                 'TipoIniciativa': 'Suscribe',
#                 'FechaIniciativa': ' 23-Septiembre-2009',
#                 'TurnoComisionI': 'NA',
#                 'SinopsisIniciativa': 'Considerar como región fronteriza, al municipio de Valle Hermoso, Tamaulipas.',
#                 'TramiteIniciativa': 'Desechada (art. 89) 16-Julio-2012 ',
#                 'GacetaIniciativa': '23-Septiembre-2009'
#             },...
#         ],
#         "PROPOSICIONES": [
#             {
#                 'NombreProposicion': 'Punto de acuerdo por el que se solicita a las ...',
#                 'TipoProposicion': 'Suscribe',
#                 'FechaProposicion': ' 23-Septiembre-2009 ',
#                 'TurnoComisionP': 'NA',
#                 'ResolutivosProponente': 'PRIMERO.- Se solicita a las instituciones ... ",
#                 'ResolutivosAprobados': 'Primero. Se desecha la proposición con punto de ...',
#                 'TramiteProposicion': 'Desechada   30-Septiembre-2010 ',
#                 'GacetaProposicion': '23-Septiembre-2009'
#             },...
#         ],
#         "ESCOLARIDAD": [
#             {
#                 'ESCOLARIDAD': 'Maestría - Master of Business Administration',
#                 'Fechas': '2005-2007'
#             },...
#         ],
#         "TRAYECTORIA POLÍTICA": [
#             {
#                 'TRAYECTORIA POLÍTICA': 'Integrante de Asambleas Nacionales - PRI',
#                 'Fechas': 'NA'
#             },...
#         ],
#         'CARGOS DE ELECCIÓN POPULAR': [
#             {
#                 'CARGOS DE ELECCIÓN POPULAR': 'Regidor, Tamaulipas - Nuevo Laredo - PRI',
#                 'Fechas': '2002-2004'
#             },...
#         ],
#         "ADMINISTRACIÓN PÚBLICA FEDERAL": [
#             {
#                 'ADMINISTRACIÓN PÚBLICA FEDERAL': 'Directora de Atención a la Juventud - ...',
#                 'Fechas': '1996-1997'
#             },...
#         ],
#         'ADMINISTRACIÓN PÚBLICA LOCAL': [
#             {
#                 'ADMINISTRACIÓN PÚBLICA LOCAL': 'Coordinadora del Programa Manos Juveniles - Ayuntamiento de Nuevo Laredo',
#                 'Fechas': '1998'
#             },...
#         ],
#         'ASOCIACIONES A LAS QUE PERTENECE': [
#             {
#                 'ASOCIACIONES A LAS QUE PERTENECE': 'Miembro - Fundación Colosio A.C., filial Nuevo Laredo',
#                 'Fechas': '11/11/2005'
#             }
#         ],
#         "ACTIVIDADES DOCENTES": [
#             {
#                'ACTIVIDADES DOCENTES': 'Invitado - Foro: ¿Por qué votar?',
#                 'Fechas': '10/06/2009'
#             },...
#         ],
#         'PUBLICACIONES': [
#             {
#                 'PUBLICACIONES': 'Política vs. Valores - Revista',
#                 'Fechas': '01/11/2000'
#             },...
#         ],
# }
#
# ```

# %% [markdown]
# **Votaciones:** La estructura de las páginas que contienen las votaciones de cada diputado se muestra a continuación
# <img src="Votaciones61.jpg" width="600">

# %% [markdown]
# Toda la información de votaciones se guardará en un diccionario llamado ***por_votaciones***, el cual tendrá esencialmente la siguiente estructura:
#
# ```css
# {'ppararcmcmcemmsacvsgmscur': {
#         'ClaveUnicaVotacion': 'ppararcmcmcemmsacvsgmscur',
#           'NombreVotacion': 'PROPOSICIÓN CON PUNTO DE ACUERDO, RELATIVO AL RETIRO DE LA CONCESIÓN DE LA MINA DE COBRE MEXICANA DE CANANEA A LA EMPRESA MINERA MÉXICO, S. A. DE C. V., SUBSIDIARIA DEL GRUPO MÉXICO. (SI SE CONSIDERA DE URGENTE RESOLUCIÓN) ',
#           'FechaVotacion': '23 Septiembre 2009',
#           'javiergilortiz': 'En contra',
#           'julianfranciscovelazquezyllorente': 'Ausente',
#           'cristabellzamoracabrera': 'En contra',
#           'edgardomelhemsalinas': 'En contra',
#           'rodolfotorrecantu': 'En contra',
#           'baltazarmanuelhinojosaochoa': 'En contra',
#           'jesuseverardovillarrealsalinas': 'En contra',
#           'josefranciscorabagocastillo': 'En contra',
#           'luisalejandroguevaracobos': 'En contra',
#           'oralialopezhernandez': 'En contra',
#           ...
#     }
# }
#
#
# ```
#
# La key *'ppararcmcmcemmsacvsgmscur'* corresponde al identificador único de la votación. El value que corresponde a dicha key es un diccionario que contiene el nombre de la votación, su respectiva fecha y los sentidos de voto de cada uno de los diputados con respecto a dicha votación.

# %% [markdown]
# **Importaciones necesarias:**
# - ***scrapy***
# - ***re***: será indispensable para la limpieza de textos
# - ***json***: la utilizaremos para la creación del archivo que contendrá la base de datos

# %%
import scrapy
import numpy as np
from scrapy.crawler import CrawlerProcess
import re
import json

# %% [markdown]
# ### Definición del Spider

# %%
class Diputados(scrapy.Spider):
    '''
        En esta sección es donde se va hacer, principalmente, el trabajo de recolección de datos,
        para su posterior procesamiento.
    '''
    name = "spider_diputados"
    
    def start_requests(self):
        '''
            Hacemos el llamado a cada una de las páginas que vamos a scrappear
        '''
        links = [urlCurr + i for i in terminaciones]
        for link in links:
            yield scrapy.Request( url = link, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:66.0) Gecko/20100101 Firefox/66.0'}, meta={'link':link},
                              callback = self.parse )
    
    def parse(self,response):
        '''
            En esta sección primero obtenemos la información del Perfil General y la vamos guardando en un diccionario
        '''
        link = response.meta['link']
        
        # Información del Perfil General
        nombre = response.css('span.Estilo67::text').extract_first()
        nombre = limpiaText(nombre)
        cumple = response.css('td.textoNegro::text').extract()[5]
        curp = creaCurp(nombre)    # Generamos el identifiador único
        dipus[curp]={}      # Declaramos el diccionario que contiene el Perfil General
        dipus.get(curp,{})['ClaveUnica']=curp
        dipus.get(curp,{})['Nombre']=nombre 
        dipus.get(curp,{})['TipoElección']=limpiaEsp(response.css('td.textoNegro::text').extract()[0])
        dipus.get(curp,{})['Entidad']=limpiaEsp(response.css('td.textoNegro::text').extract()[1])
        parti=response.xpath('//tr/td/table//td//img/@src').extract()[1]
        dipus.get(curp,{})['Partido']=obtienePartido(parti)
        dipus.get(curp,{})['Distrito']=limpiaEsp(response.css('td.textoNegro::text').extract()[2])
        dipus.get(curp,{})['Curul'] =limpiaEsp(response.css('td.textoNegro::text').extract()[4])
        dipus.get(curp,{})['Correo']=response.css('a.linkNegroSin::text').extract()[0]
        dipus.get(curp,{})['FechaNacimiento']=limpiaEsp(cumple)
        supl=response.css('span.Estilo67::text').extract()[6]
        dipus.get(curp,{})['Suplente']=limpiaText(supl)
        dipus.get(curp,{})['UltimoGrado']=response.xpath('//td[@class="textoNegro"]/text()').extract_first()
        dipus.get(curp,{})['PaginaInternet'] = link
        
        # Obtenemos la tabla de la ficha curricular sin procesar
        exp_lista=response.css("table table td").extract()
        exp_lista=exp_lista[26:len(exp_lista)]
        exp_texto = response.css("table table td::text").extract()
        exp_texto=exp_texto[11:len(exp_texto)]
        
        
        # Obtenemos la tabla de las comisiones sin procesar
        comisiones = response.xpath("//td[contains(@align, 'left')]").extract()[5]
        
        # Guardamos las 3 listas
        dic_experiencia_lista[curp] = exp_lista
        dic_experiencia_texto[curp] = exp_texto
        dic_comisiones[curp] = comisiones
        
        # Obtenemos el link que nos redirige a la página que contiene los periodos ordinarios y extraordinarios
        link_iniciativas=urlDipu + response.css('a.linkBlancoSin::attr(href)').extract()[0]
        link_proposiciones=urlDipu + response.css('a.linkBlancoSin::attr(href)').extract()[1]
        link_votaciones=urlDipu + response.css('a.linkBlancoSin::attr(href)').extract()[3]
        
        # Inicializamos los diccionarios donde vamos a guardar las proposiciones e iniciativas
        dic_proposiciones[curp] = []
        dic_iniciativas[curp]=[]
        
        # Mandamos el link de iniciativas recién obtenido 
        yield response.follow(url=link_iniciativas, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:66.0) Gecko/20100101 Firefox/66.0'},meta={'curp':curp},
                              callback=self.parse6)
        # Mandamos el link de proposiciones recién obtenido 
        yield response.follow(url=link_proposiciones, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:66.0) Gecko/20100101 Firefox/66.0'},meta={'curp':curp},
                              callback=self.parse8)
        # Mandamos el link de votaciones recién obtenido 
        yield response.follow(url=link_votaciones, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:66.0) Gecko/20100101 Firefox/66.0'},meta={'curp':curp},
                              callback=self.parse4)
    
    def parse6(self,response):
        '''
            Dentro de esta sección se encuentran los links para cada uno de los periodos. Los guardamos y, uno por uno,
            los visitamos para obtener las iniciativas de cada periodo.
        '''
        curp = response.meta['curp']
        referencias = response.xpath('//a[@class="linkVerde"]/@href').extract()
        links = [urlDipu + referencia for referencia in referencias]
        for li in links:
            yield response.follow(url=li, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:66.0) Gecko/20100101 Firefox/66.0'},meta={'curp':curp},
                              callback=self.parse7)
    
    def parse7(self,response):    
        '''
            En esta sección extraemos la tabla de iniciativas del periodo en el que nos encontremos
        '''
        curp = response.meta['curp']
        listaInic = response.css('td.Estilo69').getall() # Obtenemos todas las entradas de la tabla
        dic_iniciativas[curp] = dic_iniciativas[curp]+ listaInic # Guardamos las entradas con el resto de los periodos
    
    def parse8(self,response):
        '''
            Dentro de esta sección se encuentran los links para cada uno de los periodos. Los guardamos y, uno por uno,
            los visitamos para obtener las proposiciones de cada periodo.
        '''
        curp = response.meta['curp']
        referencias = response.xpath('//a[@class="linkVerde"]/@href').extract()
        links = [urlDipu + referencia for referencia in referencias]
        for li in links:
            yield response.follow(url=li, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:66.0) Gecko/20100101 Firefox/66.0'},meta={'curp':curp},
                              callback=self.parse9)
    def parse9(self,response):  
        '''
            En esta sección extraemos la tabla de proposiciones del periodo en el que nos encontremos
        '''
        curp = response.meta['curp']
        listaPropos = response.css('td.Estilo69').getall() # Obtenemos todas las entradas de la tabla
        dic_proposiciones[curp]= dic_proposiciones[curp]+listaPropos # Guardamos las entradas con el resto de los periodos

        
    def parse4(self,response):
        '''
            Dentro de esta sección se encuentran los links para cada uno de los periodos. Los guardamos y, uno por uno,
            los visitamos para obtener las votaciones de cada periodo.
        '''
        curp = response.meta['curp']
        referencias = response.xpath('//a[@class="linkVerde"]/@href').extract()
        links = [urlDipu + referencia for referencia in referencias]
        for li in links:
            yield response.follow(url=li, headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:66.0) Gecko/20100101 Firefox/66.0'},meta={'curp':curp},
                              callback=self.parse5)
                
    def parse5(self,response):
        '''
            En esta sección obtendremos los sentidos del voto del periodo en cuestión.
            El diccionario por_votaciones es el encargado de guardar en sus keys el identificador único de cada votación y 
            en sus values el diccionario que contiene el nombre de la votación, la fecha de la votación y el sentido del voto
            de cada uno de los diputados con respecto a dicha votación.
            La estructura de este diccionario por_votaciones es precisamente la mencionada en el ejemplo del principio del
            documento.
        '''
        curp = response.meta['curp']
        aux = response.xpath('//td[@class="smallVerde"]/text()').extract()
        todas_celdas=response.xpath('//td/text()').extract()[7:]
        j=2; 
        fechaVotacion=todas_celdas[0] 
        for i in range(1,len(aux),4):
            celda = todas_celdas[j] 
            votacion = response.xpath('//td[@class="smallVerde"]/text()').extract()[i] # Extraemos el nombre de la votación
            posi = response.xpath('//td[@class="smallVerde"]/text()').extract()[i+2]   # Extraemos el sentido del voto del diputado
            id_voto = limpiaVotacion(votacion)        # Obtenemos el identificador único de la votación
            if(id_voto in por_votaciones.keys()): 
                por_votaciones[id_voto][curp]=posi   # Si la votación ya se encontraba registrada, únicamente guardamos el sentido del voto
            else:       # Si la votación aún no se había registrado, guardamos tanto su nombre como su identificador único, así como el sentido del voto
                por_votaciones[id_voto] = {"ClaveUnicaVotacion":id_voto,"NombreVotacion":votacion, "FechaVotacion": fechaVotacion, curp:posi}
            if(i+4<len(aux)):       # Si encontramos una instancia de class = 'smallVerde', significa que las siguientes votaciones pertenecen a una nueva fecha
                if(todas_celdas[j+4]!=response.xpath('//td[@class="smallVerde"]/text()').extract()[i+4]): 
                    fechaVotacion=todas_celdas[j+3]  # cambiamos a la nueva fecha
                    j=j+5 
                else: 
                    j=j+4

# %% [markdown]
# ## Procesamiento de Datos
# ### Limpieza Perfil General

# %%
def creaCurp(nombre):
    '''
        Como identificador único de cada diputado tomamos su nombre en minúsculas, sin espacios, acentos o símbolos
    '''
    curp = nombre.replace('.', '')
    curp = nombre.replace('-', '')
    curp = curp.replace(' ', '')
    curp = curp.replace('(DECESO)', '')
    curp = curp.replace('(Deceso)', '')
    curp = curp.lower()
    curp = curp.replace('á', 'a')
    curp = curp.replace('é', 'e')
    curp = curp.replace('í', 'i')
    curp = curp.replace('ó', 'o')
    curp = curp.replace('ú', 'u')
    #curp = curp.replace('ñ', 'n')
    return curp

# %%
def limpiaText(nom):
    '''
        Esta función nos sirve para limpiar las información obtenida, quitando ciertas cadenas específicas
    '''
    resp = re.sub('\s+',' ',nom)
    resp = resp.replace('Dip. ', '')
    resp = resp.replace('(LICENCIA)', '')
    resp = resp.replace('Suplente: ', '')
    resp = resp.replace('  ', ' ')
    if(resp[-1]==" "):
        resp = resp[0:len(resp)-1]    # Evita que nuestro string contenga un espacio al final
    if(resp[0]==" "):
        resp = resp[1:]               # Evita que nuestro string contenga un espacio al principio
    return resp

# %%
def limpiaEsp(nom):
    '''
        Similar a limpiaText, pero se enfoca únicamente en eliminar espacios innecesarios
    '''
    resp = re.sub('\s+',' ',nom)
    resp = resp.replace('  ', ' ')
    if(resp!=" "):
        if(resp[-1]==" "):
            resp = resp[0:len(resp)-1]
        if(resp[0]==" "):
            resp = resp[1:]
    return resp

# %%
def obtienePartido(imagen):
    '''
        Dado que el sitio del que obtenemos los datos (sitl.diputados.gob.mx) no indica
        el partido al que pertenece un diputado más que a través de una imagen, nos corresponde obtener dicho dato
        por medio del nombre de la imagen correspondiente.
        Esta función recibe el nombre de la imagen y devuelve en un string el partido del diputado.
    '''
    res=""
    if(imagen=='images/pan.png'):
        res = "PAN"
    elif(imagen=='images/logpt.jpg'):
        res = "PT"
    elif(imagen=='images/LogoMorena.jpg'):
        res = "Morena"
    elif(imagen=='images/encuentro.png'):
        res = "Encuentro Social"
    elif(imagen=='images/logo_movimiento_ciudadano.png'):
        res = "Movimiento Ciudadano"
    elif(imagen=='images/pri01.png'):
        res = "PRI"
    elif(imagen=='images/logvrd.jpg'):
        res = "Partido Verde"
    elif(imagen=='images/prd01.png'):
        res = "PRD"
    elif(imagen=='images/logo_SP.jpg'):
        res = "Sin Partido"
    elif(imagen=="images/panal.gif"):
        res = "Nueva Alianza"
    elif(imagen=="images/independiente.png"):
        res = "Independiente"
    elif(imagen=="images/pasc.jpg"):
        res = "PSD"
    elif(imagen=="images/convergencia.gif"):
        res = "Convergencia"
    else:
         res = "Sin Partido"
    return res

# %% [markdown]
# ### Limpieza Proposiciones

# %%
def limpiaPropos(listaProp):
    '''
        Esta función recibe la tabla de proposiciones obtenida por nuestro
        Spider y se encarga de extaer la información de cada una de las 5 columnas.
        Cada renglón de la corresponde a una proposición y de cada columna se extraen múltiples datos.
        La 1a columna nos indica el nombre y tipo de la iniciativa (De grupo, proponente o Diversos Grupos Parlamentarios)
        La 2a columna nos dan las comisiones en turno y la fecha de presentación.
        La 3a columna nos da los resolutivos del proponente
        La 4a columna los resolutivos aprobados
        La 5a y última nos da el trámite en el que se encuentra la proposición y la fecha del mismo, así
        como la fecha de publicación en Gaceta
        Estos datos de cada proposición se guardan como diccionario, por lo que esta función devuelve
        la tabla de proposiciones condensada en una lista de diccionarios.
        Debido a la estructura tan diferente de cada una de las columnas, cada una requiere de su propio
        proceso de limpieza de texto
    '''
    n=len(listaProp)
    listaFinal=list()
    for i in range(0,n,5):
        renglon = listaProp[i:i+5]  # Seleccionamos las 5 columnas del renglón
        
        #Columna1
        casilla = renglon[0]        # La primera entrada del renglón corresponde a la primera columna
        resp = re.sub('\s+',' ',casilla)
        resp = resp.replace('<br>', '')
        resp = resp.replace('</span>', '')
        entrada=re.split('</b> |<span class="Estilo71">',resp)
        iniciativa=entrada[2]      # Extraemos el nombre de la proposición
        tipo = re.split('<b>',entrada[3])[0].replace(': ','')  # Obtenemos el tipo de proposición
                
        #Columna2     
        texto2=renglon[1]
        listaProp2=texto2.split('<span class="Estilo71">')
        casilla2 = listaProp2[1]
        resp2 = re.sub('\s+',' ',casilla2)
        resp2 = resp2.replace('<br>', '')
        resp2 = resp2.replace('</span>', '')
        resp2 = resp2.replace('</b>', '')
        resp2 = resp2.replace('</td>', '')
        entrada2=re.split('<b>',resp2)
        fechaPres = entrada2[1]         # Obtenemos la fecha de presentación
        if(2 in range(-len(entrada2), len(entrada2))):
            clasif=entrada2[2].replace('- ', '')     # Obtenemos la comisión en turno
        else:
            clasif="NA"      # No se especificó comisión en turno
        
        #Columna3
        casilla3=renglon[2]
        sinopsis = casilla3.replace('</td>', '')
        sinopsis = sinopsis.replace('</span>', '')
        sinopsis = sinopsis.replace('<br>', '')
        sinopsis=sinopsis.split('<span class="Estilo71">')[1]  # Obtenemos los resolutivos del proponente
        
        #Columna4
        casilla4=renglon[3]
        sinopsis2 = casilla4.replace('</td>', '')
        sinopsis2 = sinopsis2.replace('</span>', '')
        sinopsis2 = sinopsis2.replace('<br>', '')
        sinopsis2=sinopsis2.split('<span class="Estilo71">')[1]  # Obtenemos los resolutivos aprovados
        
        #Columna5
        casilla5=renglon[4]
        listaProp3=re.split('<span class="Estilo71">',casilla5)  
        resp3 = re.sub('\s+',' ',listaProp3[1])
        resp3 = resp3.replace('</td>', '')
        resp3 = resp3.replace('</span>', '')
        resp3 = resp3.replace(' </b>', '')
        resp3 = resp3.replace('<br>', '')
        status = resp3.replace('</a>', '')    
        ultimo = re.split('</b>',status)[0].replace('<b>', '')

        fecha_op = re.split('</b>',status)[1]
        fecha_op = re.sub('\s+',' ',fecha_op)
        fecha_op = fecha_op.replace('</td>', '')
        fecha_op = fecha_op.replace('</span>', '')
        fecha_op = fecha_op.replace('<b>', '')
        fecha_op = fecha_op.replace('<br>', '')
        fecha_op = fecha_op.replace('</a>', '')
        fecha_op = fecha_op.replace('con fecha', '')

        tramite = ultimo + fecha_op # Obtenemos el trámite en el que se encuentra la proposición con su respectiva fecha

        publicacion = listaProp3[2]  
        pub_final=re.split('<b>',publicacion)[1]
        pub_final = pub_final.replace('</td>', '')
        pub_final = pub_final.replace('</span>', '')
        pub_final = pub_final.replace('</b>', '')
        pub_final = pub_final.replace('<br>', '')
        pub_final = pub_final.replace('</a>', '')  # Extraemos la fecha de publicación

        listaFinal.append({"NombreProposicion": iniciativa,"TipoProposicion": tipo,"FechaProposicion":fechaPres,"TurnoComisionP":clasif,"ResolutivosProponente":sinopsis,"ResolutivosAprobados":sinopsis2,"TramiteProposicion":tramite, "GacetaProposicion":pub_final})
    return listaFinal

# %% [markdown]
# ### Limpieza Iniciativas

# %%
def limpiaInici(listaProp):
    '''
        Esta función recibe la tabla de iniciativas obtenida por nuestro
        Spider y se encarga de extaer la información de cada una de las 4 columnas.
        Cada renglón de la corresponde a una iniciativa y de cada columna se extraen múltiples datos.
        La 1a columna nos indica el nombre y tipo de la iniciativa (De grupo, proponente o Diversos Grupos Parlamentarios)
        La 2a columna nos dan las comisiones en turno y la fecha de presentación.
        La 3a columna nos da la sinopsis
        La 4a y última nos da el trámite en el pleno y la fecha del mismo, así como la fecha de publicación en Gaceta
        Estos datos de cada iniciativa se guardan como diccionario, por lo que esta función devuelve la 
        tabla de iniciativas condensada en una lista de diccionarios.
        Debido a la estructura tan diferente de cada una de las columnas, cada una requiere de su propio
        proceso de limpieza de texto
    '''
    n=len(listaProp)
    listaFinal=list()
    for i in range(0,n,4):
        renglon = listaProp[i:i+4] # Seleccionamos las 4 columnas del renglón
        #Columna1
        casilla = renglon[0]     # La primera entrada del renglón corresponde a la primera columna
        resp = re.sub('\s+',' ',casilla)
        resp = resp.replace('<br>', '')
        resp = resp.replace('</span>', '')
        entrada=re.split('</b> |<span class="Estilo71">',resp)
        iniciativa=entrada[2]        # Extraemos el nombre de la proposición
        tipo = re.split('<b>',entrada[3])[0].replace(': ','')   # Obtenemos el tipo de proposición
        
        #Columna2
        texto2=renglon[1]
        listaProp2=texto2.split('</span>')
        casilla2 = listaProp2[0]#
        resp2 = re.sub('\s+',' ',casilla2)
        resp2 = resp2.replace('<br>', '')
        resp2 = resp2.replace('<span class="Estilo71">', '')
        resp2 = resp2.replace('</b>', '')
        resp2 = resp2.replace('</td>', '')
        entrada2=re.split('<b>',resp2)
        fechaPres = entrada2[1]     # Obtenemos la fecha de presentación
        
        
        
        resp3 = re.sub('\s+',' ',listaProp2[1])
        resp3 = resp3.replace('<br>', '')
        resp3 = resp3.replace('<span class="Estilo71">', '')
        resp3 = resp3.replace('</b>', '')
        resp3 = resp3.replace('</td>', '')
        entrada3=resp3.replace('<b>','')
        if(entrada3!=' '):
            if(entrada3[0]==' ' and entrada3[1]=='-' and entrada3[2]==' '):
                entrada3=entrada3[3:]
        else:
            entrada3='NA'
        clasif=entrada3      # Obtenemos la comisión en turno  
        
        
        #Columna3
        casilla3=renglon[2]
        sinopsis = casilla3.replace('</td>', '')
        sinopsis = sinopsis.replace('</span>', '')
        sinopsis=sinopsis.split('<span class="Estilo71">')[1]  # Obtenemos la sinopsis
        
        #Columna4
        casilla4=renglon[3]
        listaProp3=re.split('<b>',casilla4)
        resp3 = re.sub('\s+',' ',listaProp3[2])
        resp3 = resp3.replace('</td>', '')
        resp3 = resp3.replace('</span>', '')
        resp3 = resp3.replace('</b>', '')
        publicacion = resp3.replace('</a>', '')   # Obtenemos la fecha de publicación
        
        parte1 = re.split('</span>',listaProp3[1])
        parte1 = re.sub('</b>',' ', parte1[0])
        status = re.sub('<br>  con fecha','',parte1)
        status = re.sub('\s+',' ',status)
        
        
        if 'linkTitulo">' in status:   # Por si la fecha viene con link
            status = re.sub('</a>','',status)
            status = re.sub(' [<>].*[<>]','',status)
        
        tramite = status    # Obtenemos el trámite en el pleno con su respectiva fecha
        
        listaFinal.append({"NombreIniciativa": iniciativa,"TipoIniciativa": tipo,"FechaIniciativa":fechaPres,"TurnoComisionI":clasif,"SinopsisIniciativa":sinopsis,"TramiteIniciativa":tramite, "GacetaIniciativa":publicacion})
    return listaFinal

# %% [markdown]
# ### Limpieza de la Ficha Curricular y las Comisiones

# %%
def obtieneComi(li):
    '''
        El listado de comisiones a las que pertenece un diputado proviene de una tabla independiente
        de aquella que contiene el perfil básico y aquella que contiene la ficha curricular. Esta función 
        recibe como único atributo la tabla de comisiones y se encarga de extraer el nombre de la comisión 
        y el tipo de la misma (Ordinaria, Grupo de Amistad, ...).
        Cada comisión se guarda en un diccionario, por lo que la función tiene como salida una lista de
        diccionarios.
    '''
    apartado=""
    comi=list()
    i=0
    while(i<len(li)-1):
        if 'span class="Estilo67">' in li[i]:    # Este 'Estilo67' nos indica cuando se encuentra el tipo de comisión
            s=li[i].split('"Estilo67">')
            apartado=s[1]               # Obtenemos el tipo
            i=i+1
        elif 'class="linkNegroSin">' in li[i]:   # Este 'linkNegroSin' nos indica cuando se encuentra el nombre de la comisión
            t=li[i].split('"linkNegroSin">')
            texto = t[1]                # Obtenemos el nombre
            comi.append({"Tipo":apartado,"Comisión":texto})
            i=i+1
        else:
            i=i+1
    return comi

# %%
def empataLis(li1,li2):
    '''
        Debido a la forma en la que la tabla de ficha curricular está estructurada, los datos faltantes crean
        un problema al querer organizar la información de la tabla. Esta función tiene como único objetivo rellenar
        los espacios en los que faltan datos con la notación 'NA', para que la estructura de la tabla se mantenga consistente
        y sea manejable en las siguientes partes del proceso'
    '''
    if(len(li1)!=len(li2)):
        for i in range(0,len(li1)):
            if '"></td>' in li1[i]: # Cuando hay un dato faltante, el código HTML no contiene texto y hace un salto de celda
                li2.insert(i, "NA") # por lo que rellenamos con la notación NA para evitar dicho salto de celda.
                if(len(li1)==len(li2)):
                    break
    return li2

# %%
def obtieneExp(curp,li1,li2,tabla_comi, liInic,liPropos,perfil_general):
    '''
        Esta función es la encargada de juntar toda la información de un diputado y guardarla en un diccionario.
        
        liInic y liPropos son las tablas de iniciativas y proposiciones, respectivamente. Se limpiarán y guardarán en listas
        de diccionarios por medio de las funciones limpiaInici y limpiaPropos antes declaradas.
        
        tabla_comi es la lista de comisiones sin procesar. Por medio de la función obtieneComi, se adquiere la lista de
        diccionarios con cada una de las comisiones
        
        perfil_general es el diccionario con la información básica ya obtenida. Este diccionario ya no requiere de mayor
        procesamiento.
        
        Los argumentos de entrada li1 y li2 proporcionarán la información de la ficha curricular con la ayuda de la
        función empataLis vista anteriormente.
        Para cada apartado de la ficha curricular (Escolaridad, Experiencia Legislativa, Trayectoria Política, ...) se genera
        una lista de diccionarios, donde cada diccionario es una entrada de cada apartado.
        
        Esta función devuelve un diccionario por diputado cuyas keys son los nombres de las tablas a guardar,
        los valores son sus respectivas listas de diccionarios. La estructura del diccionario de salida es precisamente la
        mencionada en el ejemplo al principio del documento.
    '''
    exp={"CURP":curp}
    exp={"PERFIL GENERAL":[perfil_general]}  # Empezamos guardando el perfil general
    tabla_comi_sep = tabla_comi.split("</")
    list_comis=obtieneComi(tabla_comi_sep)   # Procesamos la tabla de comisiones
    if list_comis!=[]:
        exp["COMISIONES"]=list_comis    # Guardamos las comisiones, si existen
    inics = limpiaInici(liInic)     # Procesamos la tabla de iniciativas
    props = limpiaPropos(liPropos)  # Procesamos la tabla de proposiciones
    exp["INICIATIVAS"]=inics        # Guardamos las iniciativas
    exp["PROPOSICIONES"]=props      # Guardamos las proposiciones
    
    if(len(list_comis)!=0):
        x = set()
        for i in list_comis:
            tip= i['Tipo']
            x.add(tip)
        numTipos = len(x)-1
        li2 = li2[1+2*numTipos + len(list_comis):]
    
    li2=empataLis(li1,li2)    # Comenzamos a procesar la ficha curricular
    
    apartado=""
    i=0
    while(i<len(li1)):
        if 'class="TitulosVerde"' in li1[i] and i+3<len(li1): # 'TitulosVerde' nos indica el comienzo de un
            if li2[i+1]!='.':#if li2[i+1]!='NA' and li2[i+1]!='.':              #  nuevo apartado de la ficha curricular
                apartado=li2[i]
                nom = apartado + ""
                exp[apartado]=[{nom:li2[i+1] + " - " + li2[i+2],"Fechas":li2[i+3]}] # Guardamos la experiencia con sus fechas
            i=i+4
        elif 'class="textoNegro"' in li1[i]:                  # 'textoNegro' nos indica que seguimos en el mismo apartado
            nom = apartado + ""
            exp[apartado].append({nom:li2[i] + " - " + li2[i+1],"Fechas":li2[i+2]}) # Guardamos la experiencia con sus fechas
            i=i+3
    return exp

# %% [markdown]
# ### Limpieza Votaciones

# %%
def limpiaVotacion(nombreVot):
    '''
        El propósito de esta función es generar un identificador único para cada una de las votaciones.
        En primer lugar, se limpia el texto eliminando algunas de las palabras más comunes. Posteriormente, 
        se eliminan signos de puntuación y se convierte todo el texto a minúsculas. Por último, se genera el identificador
        con la primera letra de cada palabra.
    '''
    nombreVot = nombreVot.replace('(', '')
    nombreVot = nombreVot.replace(')', '')
    nombreVot = nombreVot.replace(' SE ', ' ')
    nombreVot = nombreVot.replace('DECRETO', '')
    nombreVot = nombreVot.replace(' QUE ', ' ')
    nombreVot = nombreVot.replace(' SE ', ' ')
    nombreVot = nombreVot.replace(' DE ', ' ')
    nombreVot = nombreVot.replace(' A ', ' ')
    nombreVot = nombreVot.replace(' LA ', ' ')
    nombreVot = nombreVot.replace(' EL ', ' ')
    nombreVot = nombreVot.replace(' POR ', ' ')
    nombreVot = nombreVot.replace(' PARA ', ' ')
    nombreVot = nombreVot.replace(' LOS ', ' ')
    nombreVot = nombreVot.replace(' LAS ', ' ')
    nombreVot = nombreVot.replace(' Y ', ' ')
    nombreVot = nombreVot.replace(' E ', ' ')
    nombreVot = nombreVot.replace(' CON ', ' ')
    nombreVot = nombreVot.replace(' LEY ', ' ')
    nombreVot = nombreVot.replace(' EN ', ' ')
    nombreVot = nombreVot.replace(' LO ', ' ')
    nombreVot = nombreVot.replace(' DEL ', ' ')
    nombreVot = nombreVot.replace('Á', 'A')
    nombreVot = nombreVot.replace('É', 'E')
    nombreVot = nombreVot.replace('Í', 'I')
    nombreVot = nombreVot.replace('Ó', 'O')
    nombreVot = nombreVot.replace('Ú', 'U')
    nombreVot = nombreVot.replace('.', ' ')
    nombreVot = nombreVot.replace(';', ' ')
    nombreVot = nombreVot.replace(',', ' ')
    nombreVot = nombreVot.replace('  ', ' ')
    nombreVot = nombreVot.lower()
    nombreFin=""
    for s in nombreVot.split():
        nombreFin+=s[0]
    return nombreFin

# %% [markdown]
# ## Ejecución del Spider
#
# Es aquí donde, después de declarar el Spider y las funciones de limpieza y procesamiento de datos, se echa a correr todo el proceso. Declaramos los 3 diccionarios que contendrán las bases de datos.
#
# * *dipus* contendrá todos los perfiles básicos
# * *por_votaciones* contará con todas las votaciones
# * *diccionario_final* será el diccionario que contendrá los perfiles básicos y además las iniciativas, proposiciones, fichas curriculares y comisiones de todos los diputados. Este diccionario se crea después de la ejecución del spider a partir de la información contenida en *dic_proposiciones*, *dic_iniciativas*, *dic_experiencia_lista*, *dic_experiencia_texto* y *dic_comisiones*

# %%
dipus={}
por_votaciones = {}
diccionario_final={}
dic_proposiciones = {}
dic_iniciativas = {}
dic_experiencia_lista = {}
dic_experiencia_texto = {}
dic_comisiones = {}

urlDipu = "http://sitllxi.diputados.gob.mx/"  
urlCurr = "http://sitllxi.diputados.gob.mx/curricula.php?dipt="  #MODIFICAR ESTO AL PASAR A 60



terminaciones = []

for i in range(0,1):
    for j in range(1,2):
        for k in range(1,3):
            terminaciones.append(str(i)+str(j)+str(k))
terminaciones.append(str(500))
terminaciones.pop(0)




# Run the Spider
process = CrawlerProcess()
process.crawl(Diputados)
process.start()
# Out:
# 2021-05-13 13:12:10 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-05-13 13:12:10 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.5, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.8.2 (tags/v3.8.2:7b3ab59, Feb 25 2020, 23:03:10) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1j  16 Feb 2021), cryptography 3.4.6, Platform Windows-10-10.0.19041-SP0
# 2021-05-13 13:12:10 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-05-13 13:12:10 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2021-05-13 13:12:10 [scrapy.extensions.telnet] INFO: Telnet Password: c79ae67225420774
# 2021-05-13 13:12:10 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-05-13 13:12:11 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-05-13 13:12:11 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-05-13 13:12:11 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-05-13 13:12:11 [scrapy.core.engine] INFO: Spider opened
# 2021-05-13 13:12:11 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-05-13 13:12:11 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=261> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=264> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=262> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=263> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=260> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=268> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=265> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=267> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=269> (referer: None)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=264> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=264)
# 2021-05-13 13:12:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=261> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=261)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=262> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=262)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=264> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=264)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=261> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=261)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=261> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=261)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=264> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=264)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=263> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=263)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=263)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=263> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=263)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=265)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=262> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=262)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=260> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=260)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=262> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=262)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=260> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=260)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=260> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=260)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=268)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/curricula.php?dipt=266> (referer: None)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=261&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=261)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=261&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=261)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=261&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=261)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=269> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=269)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=269> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=269)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=264&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=264)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=264&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=264)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=269)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=264&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=264)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=264&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=264)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=262&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=263&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=260&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=263&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=260&pert=5> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=263&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=260&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:12:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=260&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:12:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=269&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=266)
# 2021-05-13 13:12:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=260&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:12:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=260&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:12:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=263&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:12:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=266> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=266)
# 2021-05-13 13:12:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=269&pert=11> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=260&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=8> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=269&pert=7> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=269&pert=5> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=269&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=4> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=269&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=269&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=269&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=269&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=266&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:12:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=269&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=266&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=269&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=266&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=266&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=266&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=266&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=266&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=266&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=266> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=266)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=266&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=266&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=266&pert=4> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=266&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=266&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=269&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=269&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=269)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=10> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=12> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:11 [scrapy.extensions.logstats] INFO: Crawled 90 pages (at 90 pages/min), scraped 0 items (at 0 items/min)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=260&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=260&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=260&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=268&pert=4> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=260&pert=7> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=260&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=266&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=266&pert=8> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=266&pert=7> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=266&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=266&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=266)
# 2021-05-13 13:13:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=262&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=262&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=260&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=260&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=262&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=262&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=262&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=260&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=260&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=262&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=262&pert=5> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=262&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=265&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=262&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=262&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=262&pert=7> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=260&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=260)
# 2021-05-13 13:13:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=265&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=265&pert=8> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=265&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=265&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=263&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=263&pert=7> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=263&pert=8> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=265&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=265&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=263&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=263&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=263&pert=8> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=263&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=263&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=263&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=263&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=261&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=261)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=261&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=261)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=263&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=264&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=264)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=263&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=261&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=261)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=263&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=263&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=263)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=262&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=262&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=262&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=262&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=267> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=267)
# 2021-05-13 13:13:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=262&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=262)
# 2021-05-13 13:13:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=267> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=267)
# 2021-05-13 13:13:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=267)
# 2021-05-13 13:13:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=261&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=261)
# 2021-05-13 13:13:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=265> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=265)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=268)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=265> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=265)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=268> (referer: http://sitllxi.diputados.gob.mx/curricula.php?dipt=268)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=267&pert=11> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=267&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=267&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=267&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=267&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=267&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=267&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=267&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=267&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=267&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:13:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=265&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=265&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=265&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=265&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=268&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=268&pert=11> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:13:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=265&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:13:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=265&pert=9> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:14:13 [scrapy.extensions.logstats] INFO: Crawled 176 pages (at 86 pages/min), scraped 0 items (at 0 items/min)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=265&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=265&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=265&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=265)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=11> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=268&pert=3> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=268&pert=1> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=10> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=268&pert=7> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=9> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/votaciones_por_pernplxi.php?iddipt=268&pert=5> (referer: http://sitllxi.diputados.gob.mx/votaciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=8> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=7> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=5> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=1> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=267&pert=12> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=267&pert=5> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=267&pert=11> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/proposiciones_por_pernplxi.php?iddipt=268&pert=3> (referer: http://sitllxi.diputados.gob.mx/proposiciones_diputados_xperiodonplxi.php?dipt=268)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=267&pert=9> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:14:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=267&pert=7> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:14:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=267&pert=1> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:14:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://sitllxi.diputados.gob.mx/iniciativas_por_pernplxi.php?iddipt=267&pert=3> (referer: http://sitllxi.diputados.gob.mx/iniciativas_diputados_xperiodonplxi.php?dipt=267)
# 2021-05-13 13:14:19 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-05-13 13:14:19 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 88751,
#  'downloader/request_count': 198,
#  'downloader/request_method_count/GET': 198,
#  'downloader/response_bytes': 4459430,
#  'downloader/response_count': 198,
#  'downloader/response_status_count/200': 198,
#  'elapsed_time_seconds': 128.316393,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 5, 13, 18, 14, 19, 571909),
#  'log_count/DEBUG': 198,
#  'log_count/INFO': 12,
#  'request_depth_max': 2,
#  'response_received_count': 198,
#  'scheduler/dequeued': 198,
#  'scheduler/dequeued/memory': 198,
#  'scheduler/enqueued': 198,
#  'scheduler/enqueued/memory': 198,
#  'start_time': datetime.datetime(2021, 5, 13, 18, 12, 11, 255516)}
# 2021-05-13 13:14:19 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### Creación de la base de datos
# Primero procesamos toda la información para llenar *diccionario_final*. Los 3 diccionarios obtenidos se guardan en 3 archivos ***json*** por separado.

# %%
diccionario_final = {}
for key, value in dipus.items():
    legislador= obtieneExp(key,dic_experiencia_lista[key],dic_experiencia_texto[key],dic_comisiones[key], dic_iniciativas[key],dic_proposiciones[key],dipus.get(key,{}))
    diccionario_final[key] = legislador

# %%
diccionario_final
# Out:
# {'jesuseverardovillarrealsalinas': {'PERFIL GENERAL': [{'ClaveUnica': 'jesuseverardovillarrealsalinas',
#     'Nombre': 'Jesús Everardo Villarreal Salinas',
#     'TipoElección': 'Mayoría Relativa',
#     'Entidad': 'Tamaulipas',
#     'Partido': 'PRI',
#     'Distrito': '2',
#     'Curul': 'I-300',
#     'Correo': 'jesus.villarreal@congreso.gob.mx ',
#     'FechaNacimiento': '23-marzo-1978',
#     'Suplente': 'Laura Felicitas García Dávila',
#     'UltimoGrado': 'Mayoría Relativa ',
#     'PaginaInternet': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt=261'}],
#   'INICIATIVAS': [{'NombreIniciativa': 'Proyecto de decreto que reforma el artículo 9°-A de la Ley de Coordinación Fiscal.',
#     'TipoIniciativa': 'Suscribe',
#     'FechaIniciativa': ' 15-Marzo-2011',
#     'TurnoComisionI': 'NA',
#     'SinopsisIniciativa': 'Actualizar el esquema de participación de fondos en beneficio de los municipios y entidades donde se ubiquen puentes, nacionales o internacionales, quienes podrán obtener hasta 50 por ciento del monto total de los ingresos brutos que se deriven de la operación de éstos.',
#     'TramiteIniciativa': 'Desechada (art. 89) 16-Julio-2012 ',
#     'GacetaIniciativa': '15-Marzo-2011'},
#    {'NombreIniciativa': 'Proyecto de decreto que reforma el artículo 2° de la Ley del Impuesto al Valor Agregado.',
#     'TipoIniciativa': 'Suscribe',
#     'FechaIniciativa': ' 15-Marzo-2011',
#     'TurnoComisionI': 'NA',
#     'SinopsisIniciativa': 'Considerar dentro de la región fronteriza al municipio de Valle Hermoso, Tamaulipas.',
#     'TramiteIniciativa': 'Desechada (art. 89) 16-Julio-2012 ',
#     'GacetaIniciativa': '15-Marzo-2011'},
#    {'NombreIniciativa': 'Proyecto de decreto que reforma y adiciona diversas disposiciones de la Ley de la Comisión Nacional de los Derechos Humanos, de la Ley General del Sistema Nacional de Seguridad Pública, de la Ley Federal de Extinción de Dominio y expide la Ley General de Protección a Víctimas del Delito, Reglamentaria del inciso c) del artículo 20 Constitucional.',
#     'TipoIniciativa': 'Adherente',
#     'FechaIniciativa': ' 4-Febrero-2010',
#     'TurnoComisionI': 'NA',
#     'SinopsisIniciativa': '
#     'TramiteProposicion': 'Aprobada   16-Febrero-2010 ',
#     'GacetaProposicion': '10-Diciembre-2009'}],
#   'ESCOLARIDAD': [{'ESCOLARIDAD': 'Licenciatura - Derecho',
#     'Fechas': '1995-1999'},
#    {'ESCOLARIDAD': 'Diplomado - Derecho Internacional del Transporte',
#     'Fechas': '1999'},
#    {'ESCOLARIDAD': 'Diplomado - Derecho Comparado', 'Fechas': 'NA'}],
#   'TRAYECTORIA POLÍTICA': [{'TRAYECTORIA POLÍTICA': 'Seccretario Adjunto del Comité Municipal de Reynosa - PRI',
#     'Fechas': '2000'},
#    {'TRAYECTORIA POLÍTICA': 'Presidente de la Comisión de los Emigrantes en el Estado - PRI',
#     'Fechas': '2002'},
#    {'TRAYECTORIA POLÍTICA': 'Delegado Estatal de la Convención para la selección de candidato al Gobierno del Estado - PRI',
#     'Fechas': '2004'},
#    {'TRAYECTORIA POLÍTICA': 'Miembro del Consejo Político Municipal - PRI',
#     'Fechas': 'NA'},
#    {'TRAYECTORIA POLÍTICA': 'Miembro del Consejo Político Estatal - PRI',
#     'Fechas': 'NA'}],
#   'EXPERIENCIA LEGISLATIVA': [{'EXPERIENCIA LEGISLATIVA': 'Diputado Local Propietario, PRI - LIX Legislatura',
#     'Fechas': '2005-2007'}],
#   'ADMINISTRACIÓN PÚBLICA LOCAL': [{'ADMINISTRACIÓN PÚBLICA LOCAL': 'Director del Consejo Juvenil Ciudadano - Presidencia Municipal de Reynosa',
#     'Fechas': '2002-2004'},
#    {'ADMINISTRACIÓN PÚBLICA LOCAL': 'Secretario de Desarrollo Social - Ayuntamiento de Reynosa',
#     'Fechas': '2007-2008'}],
#   'INICIATIVA PRIVADA': [{'INICIATIVA PRIVADA': 'Director General - Servicios Ecológicos, VIDSA S.A. de C.V.',
#     'Fechas': '2004-2009'}],
#   'CARGOS EN LEGISLATURAS LOCALES O FEDERALES': [{'CARGOS EN LEGISLATURAS LOCALES O FEDERALES': 'Secretario de la Comisión de la Juventud, Congreso de Tamaulipas - LIX Legislatura',
#     'Fechas': ' '},
#    {'CARGOS EN LEGISLATURAS LOCALES O FEDERALES': 'Presidente de la Comisión Cuenca de Burgos y Desarrollo del Estado, Congreso de Tamaulipas - LIX Legislatura',
#     'Fechas': ' '}]},
#  'rodolfotorrecantu': {'PERFIL GENERAL': [{'ClaveUnica': 'rodolfotorrecantu',
#     'Nombre': 'Rodolfo Torre Cantú',
#     'TipoElección': 'Mayoría Relativa',
#     'Entidad': 'Tamaulipas',
#     'Partido': 'PRI',
#     'Distrito': '5',
#     'Curul': 'I-301',
#     'Correo': 'rodolfo.torre@congreso.gob.mx ',
#     'FechaNacimiento': '14-febrero-1964',
#     'Suplente': 'Morelos Jaime Carlos Canseco Gómez',
#     'UltimoGrado': 'Mayoría Relativa ',
#     'PaginaInternet': 'http://sitllxi.diputados.gob.mx/curricula.php?dipt
Ley Orgánica del Congreso General de los Estados Unidos Mexicanos, la Junta de Coordinación Política presentará al pleno una propuesta de integración plural de esta comisión especial.  CUARTO.- La comisión especial deberá contará con los recursos y personal necesario para su operación y su duración será hasta el término de la actual legislatura o cuando se haya cumplido su objeto.',
#     'ResolutivosAprobados': '.',
#     'TramiteProposicion': 'Pendiente ',
#     'GacetaProposicion': '1-Octubre-2009'},
#    {'NombreProposicion': 'Punto de Acuerdo por el que se exhorta a la Comisión de Hacienda y Crédito Público de esta Soberanía, para que en el proyecto de Ley de Ingresos para el ejercicio fiscal 2010, no apruebe el incremento del Impuesto Especial sobre Producción y Servicios, de tres puntos porcentuales a la cerveza.',
#     'TipoProposicion': 'Suscribe',
#     'FechaProposicion': ' 13-Octubre-2009 ',
#     'TurnoComisionP': 'NA',
#     'ResolutivosProponente': 'ÚNICO.- Se exhorta a la Comisión de Hacienda y Crédito Público de esta honorable Cámara de Diputados a efecto de que en el análisis, discusión y dictamen del proyecto de Ley de Ingresos para el ejercicio de 2010 no apruebe el incremento del impuesto especial sobre producción y servicios de 3 puntos porcentuales a la cerveza.',
#     'ResolutivosAprobados': '.',
#     'TramiteProposicion': 'Desechada (art. 184, num 2)   16-Julio-2012 ',
#     'GacetaProposicion': '13-Octubre-2009'},
#    {'NombreProposicion': 'Punto de Acuerdo para que a través de la Comisión de Atención a Grupos Vulnerables, se realice un foro conmemorativo al Vigésimo Aniversario de la Convención sobre los Derechos del niño, con el propósito de llevar a cabo una revisión de los avances y retos legislativos nacionales en la materia.',
#     'TipoProposicion': 'Suscribe',
#     'FechaProposicion': ' 20-Octubre-2009 ',
#     'TurnoComisionP': 'NA',
#     'ResolutivosProponente': 'ÚNICO.-La honorable Cámara de Diputados aprueba convocar y organizar un foro conmemorativo del vigésimo aniversario de la Convención sobre los Derechos del Niño, a través de la Comisión de Atención a Grupos Vulnerables, el 19 y el 20 de noviembre de 2009, con la finalidad de fortalecer la agenda legislativa de dicha Comisión y a fin de garantizar plenamente los derechos de niñas, niños y adolescentes en México.',
#     'ResolutivosAprobados': 'PRIMERO.- La Cámara de Diputados de la LXI Legislatura del honorable Congreso de la Unión aprueba convocar y organizar un foro conmemorativo del vigésimo aniversario de la Convención sobre los Derechos del Niño. SEGUNDO.- La Comisión de Atención a Grupos Vulnerables, en nombre de la Cámara de Diputados, se encargará de organizar dicho foro que se celebrará el 19 y el 20 de noviembre de 2009 en las instalaciones del Palacio Legislativo de San Lázaro. TERCERO.- Los grupos parlamentarios asumirán las conclusiones del foro, que en el marco de sus atribuciones le competan desahogar por las vías expresas en la ley.',
#     'TramiteProposicion': 'Aprobada   4-Noviembre-2009 ',
#     'GacetaProposicion': '15-Octubre-2009'}],
#   'ESCOLARIDAD': [{'ESCOLARIDAD': 'Licenciatura - Médico Cirujano',
#     'Fechas': 'NA'}],
#   'TRAYECTORIA POLÍTICA': [{'TRAYECTORIA POLÍTICA': 'Presidente del Comité Municipal - PRI',
#     'Fechas': 'NA'}],
#   'ADMINISTRACIÓN PÚBLICA FEDERAL': [{'ADMINISTRACIÓN PÚBLICA FEDERAL': 'Jefe del Departamento de Servicios Médicos - Banco de Crédito Rural del Noreste',
#     'Fechas': 'NA'}],
#   'ADMINISTRACIÓN PÚBLICA LOCAL': [{'ADMINISTRACIÓN PÚBLICA LOCAL': 'Director del DIF - Municipio de Victoria',
#     'Fechas': '1999-2001'},
#    {'ADMINISTRACIÓN PÚBLICA LOCAL': 'Secretario de Salud - Gobierno del Estado de Tamaulipas',
#     'Fechas': '2005-2009'}]},
#  'edgardomelhemsalinas': {'PERFIL GENERAL': [{'ClaveUnica': 'edgardomelhemsalinas',
#     'Nombre': 'Edgardo Melhem Salinas',
la Ley Federal de Presupuesto y Responsabilidad Hacendaria, a efecto de subsanar los subejercicios que se presentan en el llamado Programa Carretero, en específico, en el ejercicio de recursos para Caminos Rurales y Carreteras Alimentadoras del país.',
#     'TramiteProposicion': 'Aprobada   17-Agosto-2011 ',
#     'GacetaProposicion': '--'},
#    {'NombreProposicion': 'Punto de acuerdo por el que se exhorta a la SCT a incluir de manera obligatoria en sus normas, referencias técnicas y manuales especificaciones para la colocación de bandas de alerta en las autopistas de cuota de la red nacional.',
#     'TipoProposicion': 'Proponente',
#     'FechaProposicion': ' 22-Febrero-2011 ',
#     'TurnoComisionP': 'NA',
#     'ResolutivosProponente': 'ÚNICO.- Se exhorta a la Secretaría de Comunicaciones y Transportes, en uso de sus atribuciones legales, a incluir de manera obligatoria en las normas, referencias técnicas y manuales, que para tal efecto expide, especificaciones para la colocación de bandas de alerta en todas las autopistas de cuota que operan actualmente, así como en los proyectos que se promuevan en lo futuro.',
#     'ResolutivosAprobados': 'ÚNICO.- La Cámara de Diputados exhorta a la Secretaría de Comunicaciones y Transportes para que en uso de sus atribuciones legales, incluya de manera obligatoria en las normas, referencias técnicas y manuales que para tal efecto expide, especificaciones para la colocación de bandas de alerta en todas las autopistas de cuota que operan actualmente, así como en los proyectos que se promuevan en lo futuro.',
#     'TramiteProposicion': 'Aprobada   27-Abril-2011 ',
#     'GacetaProposicion': '22-Febrero-2011'},
#    {'NombreProposicion': 'Punto de acuerdo por el que se exhorta a la SCT a revertir a favor del dominio público los tramos de vía ferroviaria en desuso y abandonada por Ferrosur entre Calpulalpan y Tláloc, Tlaxcala, a fin de donarlos a esas comunidades para obras de beneficio social.',
#     'TipoProposicion': 'Proponente',
#     'FechaProposicion': ' 22-Febrero-2011 ',
#     'TurnoComisionP': 'NA',
#     'ResolutivosProponente': 'ÚNICO.- Se exhorta a la Secretaría de Comunicaciones y Transportes para que revierta a favor del dominio público los tramos de vía ferroviaria en desuso y abandonada por la empresa concesionaria Ferrosur, comprendidos entre Calpulalpan y Tláloc, Tlaxcala, con la finalidad de que sean donados a esas comunidades para obras de beneficio social.',
#     'ResolutivosAprobados': '.',
#     'TramiteProposicion': 'Desechada (art. 184, num 2)   20-Octubre-2011 ',
#     'GacetaProposicion': '22-Febrero-2011'},
#    {'NombreProposicion': 'Punto de acuerdo por el que se exhorta al Ejecutivo federal, para que a través de la Secretaría de Economía y de Pemex, haga público el proceso de autorización para la inversión neutra en la industria petrolera del país.',
#     'TipoProposicion': 'Proponente',
#     'FechaProposicion': ' 28-Abril-2011 ',
#     'TurnoComisionP': 'NA',
#     'ResolutivosProponente': 'ÚNICO.- La Cámara de Diputados exhorta al Ejecutivo federal a hacer público por la Secretaría de Economía y Petróleos Mexicanos el proceso de autorización a extranjeros para la inversión neutra en un sector estratégico como el de embarcaciones al servicio de la industria petrolera del país.',
#     'ResolutivosAprobados': '.',
#     'TramiteProposicion': 'Desechada (art. 184, num 2)   -- ',
#     'GacetaProposicion': '28-Abril-2011'},
#    {'NombreProposicion': 'Punto de acuerdo por el que se solicita a la Secretaría de Comunicaciones y Transportes, instale sistemas de aterrizaje por instrumentos en el aeropuerto de Nuevo Laredo, Tamaulipas.',
#     'TipoProposicion': 'Suscribe',
#     'FechaProposicion': ' 17-Marzo-2010 ',
#     'TurnoComisionP': 'NA',
#     'ResolutivosProponente': 'ÚNICO.- Se solicita a la Secretaría de Comunicaciones y Transportes que a través de Aeropuertos y Servicios Auxiliares modernice e instale a la mayor brevedad posible en el aeropuerto internacional Quetzalcóatl sistemas especializados para aterrizaje por instrumentos, con objeto principal de salvaguardar, esencialmente, la vida de usuarios, personal aéreo y de tierra y no interrumpir el potencial de desarrollo económico, industrial y comercial que para nuestro país representa Nuevo Laredo, Tamaulipas.',
#     'ResolutivosAprobados': 'ÚNICO.- La Cámara de Diputados exhor
#    {'NombreProposicion': 'Punto de Acuerdo para que en el Proyecto de Presupuesto de Egresos de la Federación para el ejercicio fiscal 2010, se consideren mayores recursos para el Fondo Metropolitano del ramo 23 ¿Provisiones Salariales y Económicas¿ y se incluya como beneficiaria a la zona metropolitana de Tampico, Madero y Altamira, Tamaulipas.',
#     'TipoProposicion': 'Proponente',
#     'FechaProposicion': ' 27-Octubre-2009 ',
#     'TurnoComisionP': 'NA',
#     'ResolutivosProponente': 'ÚNICO.- Se exhorta a las Comisiones de Desarrollo Metropolitano, y de Presupuesto y Cuenta Pública de esta honorable Cámara de Diputados del Congreso de la Unión a incrementar en el Presupuesto de Egresos de la Federación del próximo año fiscal 2010 el Fondo Metropolitano del Ramo 23, "Provisiones salariales y económicas", e incluir como beneficiaria la zona metropolitana de Tampico, Madero y Altamira, Tamaulipas.',
#     'ResolutivosAprobados': 'Primero. Con fundamento en los artículos 45, numeral 6, incisos e) y f), de la Ley Orgánica del Congreso General de los Estados Unidos Mexicanos; 18 y 42, fracción VIII, incisos b) y c), de la Ley Federal de Presupuesto y Responsabilidad Hacendaria, y derivado de que los puntos de acuerdo descritos en el numeral I de los antecedentes del presente acuerdo, fueron revisados, analizados y discutidos en la dictaminación del Presupuesto de Egresos para el Ejercicio Fiscal de 2010 se tienen por atendidas todas las proposiciones con puntos de acuerdo en comento.  Segundo. Las proposiciones con puntos de acuerdo descritas en el numeral II de los antecedentes de este acuerdo, carecen de materia, toda vez que no se presentaron en tiempo para su estudio, análisis y valoración para ser consideradas en el proyecto de Presupuesto de Egresos para el Ejercicio Fiscal de 2010.',
#     'TramiteProposicion': 'Atendida   9-Marzo-2010 ',
#     'GacetaProposicion': '27-Octubre-2009'}],
#   'ESCOLARIDAD': [{'ESCOLARIDAD': 'Licenciatura - Ing. Civil',
#     'Fechas': '1981-1985'}],
#   'TRAYECTORIA POLÍTICA': [{'TRAYECTORIA POLÍTICA': 'Asesor Político del Comité Directivo Estatal del Organismo Nacional de Mujeres Priístas - PRI',
#     'Fechas': 'NA'}],
#   'CARGOS DE ELECCIÓN POPULAR': [{'CARGOS DE ELECCIÓN POPULAR': 'Presidente Municipal, Tamaulipas - Altamira - PRI',
#     'Fechas': '2008-2009'}],
#   'ADMINISTRACIÓN PÚBLICA LOCAL': [{'ADMINISTRACIÓN PÚBLICA LOCAL': 'Gerente General - COMAPA',
#     'Fechas': 'Enero de 2005-febrero de 2006'},
#    {'ADMINISTRACIÓN PÚBLICA LOCAL': 'Coordinador - Unidos Avanzamos Más',
#     'Fechas': 'Marzo de 2006-julio de 2007'}],
#   'INICIATIVA PRIVADA': [{'INICIATIVA PRIVADA': 'Socio y Consejero - Educadora Columbia, S.C. Educación Preescolar, Primaria y Secundaria',
#     'Fechas': '15 años'},
#    {'INICIATIVA PRIVADA': 'Socio y Director General - Edificadora Golfo Norte, S.A. de C.V. Construcción',
#     'Fechas': '17 años'},
#    {'INICIATIVA PRIVADA': 'Socio y Accionista - Río Tigre Acuacultores, S.A. de C.V. Granja de Engorda de Camarón',
#     'Fechas': '7 años'}],
#   'Actividad Empresarial': [{'Actividad Empresarial': 'Arrendatario - Francisco Javier Gil Ortíz ',
#     'Fechas': '4 años'}]}}

# %%
with open('BaseCurricula61.json', 'a') as f:
            json.dump(diccionario_final, f, indent=4, ensure_ascii=False)

# %%
with open('PerfilesBasicos61.json', 'a') as f:
            json.dump(dipus, f, indent=4, ensure_ascii=False)

# %%
with open('BaseVotaciones61.json', 'a') as f:
            json.dump(por_votaciones, f, indent=4, ensure_ascii=False)

# %% [markdown]
# De manera similar, si así se desea, los diccionarios se pueden convertir a lista de diccionarios y guardarlos en esa estructura.

# %%
#list_perfiles_basicos = [value for value in dipus.values()]

# %%
#list_of_votos = [value for value in por_votaciones.values()]

# %%
#list_legisladores = [value for value in diccionario_final.values()]

# %%
#with open('PerfilesBasicos_FormatoLista.json', 'a') as f:
#            json.dump(list_perfiles_basicos, f, indent=4, ensure_ascii=False)

# %%
#with open('Curricula_FormatoLista.json', 'a') as f:
#            json.dump(list_legisladores, f, indent=4, ensure_ascii=False)

# %%
#with open('Votaciones_FormatoLista.json', 'a') as f:
#            json.dump(list_of_votos, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ### Visualizando los datos
# Esta sección sirve meramente como apoyo visual. Requiere que en la última sección los diccionarios *dipus*, *por_votaciones* y *diccionario_final* se pasen a estructura lista de diccionarios.

# %%
# Visualizamos en formato Dataframe los perfiles básicos
perfil_legislador = pd.DataFrame(list_perfiles_basicos)
#perfil_legislador

# %%
# Visualizamos en formato Dataframe las votaciones
perfil_votos = pd.DataFrame(list_of_votos)
#perfil_votos

# %%
# En este corto apartado, se selecciona arbitrariamente un diputado en específico y se obtiene el nombre de cada una de
# las tablas de la cual se tiene información del diputado seleccionado

diputadoX=list_legisladores[2] # Seleccionamos un diputado

lista_tablas=[]
for key in diputadoX:
    print(key)
    df = pd.DataFrame(diputadoX[key])
    lista_tablas.append(df)

# %%
# Con base en la selección del diputado, se puede consultar cada una de las tablas disponibles

df=lista_tablas[3] # Seleccionamos la tabla que deseamos visualizar

# %%
por_votaciones
# Out:
# {'ra37bcpafgp': {'ClaveUnicaVotacion': 'ra37bcpafgp',
#   'NombreVotacion': 'DECRETO QUE REFORMA LOS ARTICULOS 37 Y 70 BIS DE LA LEY DE CAMINOS, PUENTES Y AUTOTRANSPORTE FEDERAL (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '2 Febrero 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'En contra',
#   'javiergilortiz': 'Ausente',
#   'edgardomelhemsalinas': 'Ausente',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'En contra'},
#  'cp1cmpauclcgegp': {'ClaveUnicaVotacion': 'cp1cmpauclcgegp',
#   'NombreVotacion': 'DECRETO QUE CONCEDE PERMISO A 1 CIUDADANO MEXICANO PARA QUE PUEDA ACEPTAR Y USAR CONDECORACION QUE LE CONFIERE GOBIERNO EXTRANJERO (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '2 Febrero 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'Ausente',
#   'edgardomelhemsalinas': 'Ausente',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'ajrpvmdcdtaepc1d2h3a2sa': {'ClaveUnicaVotacion': 'ajrpvmdcdtaepc1d2h3a2sa',
#   'NombreVotacion': 'ACUERDO DE LA JUCOP RELATIVO A LA PRIMERA VICEPRESIDENCIA DE LA MESA DIRECTIVA DE LA CAMARA DE DIPUTADOS DEL TERCER AÑO DE EJERCICIO, PARA EL PERIODO COMPRENDIDO DEL 16 DE DICIEMBRE DE 2011 HASTA EL 30 DE ABRIL DE 2012 (SI SE APRUEBA) ',
#   'FechaVotacion': '7 Febrero 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'radddrtaippdpcdgp': {'ClaveUnicaVotacion': 'radddrtaippdpcdgp',
#   'NombreVotacion': 'DECRETO QUE REFORM
EN LO GENERAL Y EN LO PARTICULAR LOS ARTICULOS NO RESERVADOS) ',
#   'FechaVotacion': '15 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'Ausente',
#   'javiergilortiz': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'egpsedmtppavedalraddlcclllparmaa': {'ClaveUnicaVotacion': 'egpsedmtppavedalraddlcclllparmaa',
#   'NombreVotacion': 'DECRETO QUE EXPIDE LA LEY GENERAL PARA PREVENIR, SANCIONAR Y ERRADICAR LOS DELITOS EN MATERIA DE TRATA DE PERSONAS Y PARA LA PROTECCION Y ASISTENCIA A LAS VICTIMAS DE ESTOS DELITOS, ABROGA LA LPPSTP; Y REFORMA Y ADICIONA DIV. DISP. DE LA LCDO, CFPP, CPF, DE LA LOPJF, DE LA LPF Y DE LA LGSNSP (EN LO PARTICULAR LOS ARTICULOS RESERVADOS CON LAS MODIFICACIONES ACEPTADAS POR LA ASAMBLEA) ',
#   'FechaVotacion': '20 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'cristabellzamoracabrera': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'ajpltpccictaippdpcdcusa': {'ClaveUnicaVotacion': 'ajpltpccictaippdpcdcusa',
#   'NombreVotacion': 'ACUERDO DE LA JUCOP POR EL QUE SE PROPONE LA LISTA DE TRES PERSONAS COMO CONSEJEROS INTEGRANTES DEL CONSEJO DE TRANSPARENCIA, ACCESO DE INF. PUBLICA Y PROTECCION DE DATOS PERSONALES DE LA CAMARA DE DIPUTADOS DEL CONGRESO DE LA UNION (SI SE APRUEBA) ',
#   'FechaVotacion': '27 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'cscp3cmpsre2cauclcgegpanr': {'ClaveUnicaVotacion': 'cscp3cmpsre2cauclcgegpanr',
#   'NombreVotacion': 'CUATRO DECRETOS QUE CONCEDEN PERMISO A 3 CIUDADANOS MEXICANOS PARA PRESTAR SERVICIOS EN REPRESENTACIONES EXTRANJERAS Y A 2 CIUDADANOS PARA ACEPTAR Y USAR CONDECORACIONES QUE LES CONFIEREN GOBIERNOS EXTRANJEROS (EN LO GENERAL Y EN LO PARTICULAR LOS ARTICULOS NO RESERVADOS) ',
#   'FechaVotacion': '27 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'cpacgggauccvlogcgp': {'ClaveUnicaVotacion': 'cpacgggauccvlogcgp',
#   'NombreVotacion': 'DECRETO POR EL QUE SE CONCEDE PERMISO AL CIUDADANO GUILLERMO GALVÁN GALVÁN, PARA ACEPTAR Y USAR LA CONDECORACIÓN CRUZ DE LA VICTORIA QUE LE OTORGA EL GOBIERNO DE CHILE (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '27 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'cpacjigauclcgegp': {'ClaveUnicaVotacion': 'cpacjigauclcgegp',
#   'NombreVotacion': 'DECRETO QUE CONCEDEN PERMISO A AL CIUDADANO JUAN IGNACIO GALLARDO PARA ACEPTAR Y USAR CONDECORACIONES QUE LES CONFIEREN GOBIERNOS EXTRANJEROS (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '27 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'radddfedra2cgp': {'ClaveUnicaVotacion': 'radddfedra2cgp',
#   'NombreVotacion': 'DECRETO QUE REFORMA, ADICIONA Y DEROGA DIVERSAS DISPOSICIONES DE LA LEY FEDERAL DE EXTINCION DE DOMINIO, REGLAMENTARIA DEL ARTICULO 22 DE LA CPEUM (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '27 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'Ausente',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'efjaaopjfroapfaopgrrfdpgpanr': {'ClaveUnicaVotacion': 'efjaaopjfroapfaopgrrfdpgpanr',
#   'NombreVotacion': 'DECRETO POR EL QUE SE EXPIDE LA LEY FEDERAL DE JUSTICIA PARA ADOLESCENTES, SE ADICIONA LA LEY ORGANICA DEL PODER JUDICIAL DE LA FEDERACION, SE REFORMA LA LEY ORG. DE LA ADMIN. PUB. FEDERAL, SE ACIONA LA LEY ORG. DE LA PROC. GRAL. DE LA REP. Y SE RFORMA LA LEY FED. DE DEFENSORIA PUB. (EN LO GRAL Y EN LO PART. LOS ARTS. NO RESERVADOS). ',
#   'FechaVotacion': '28 Marzo 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  
S (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '10 Abril 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'qra4gegp': {'ClaveUnicaVotacion': 'qra4gegp',
#   'NombreVotacion': 'DECRETO QUE QUE REFORMA EL ARTICULO 46 DE LA LEY GENERAL DE EDUCACION (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '10 Abril 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'epvmdsa': {'ClaveUnicaVotacion': 'epvmdsa',
#   'NombreVotacion': 'ELECCION DE LA PRIMER VICEPRESIDENCIA DE LA MESA DIRECTIVA  (SI SE APRUEBA) ',
#   'FechaVotacion': '11 Abril 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'raddcpafmstgp': {'ClaveUnicaVotacion': 'raddcpafmstgp',
#   'NombreVotacion': 'DECRETO QUE REFORMA Y ADICIONA DIVERSAS DISPOSICIONES DE LA LEY DE CAMINOS,  PUENTES Y AUTOTRANSPORTE FEDERAL,  EN MATERIA DE SEGURO A TERCEROS (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '11 Abril 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'A favor',
#   'oralialopezhernandez': 'A favor'},
#  'rfia1isrgp': {'ClaveUnicaVotacion': 'rfia1isrgp',
#   'NombreVotacion': 'DECRETO QUE REFORMA LA FRACCION III DEL ARTICULO 109 DE LA LEY DEL IMPUESTO SOBRE LA RENTA (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '11 Abril 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'ecumc1abp5m1gp': {'ClaveUnicaVotacion': 'ecumc1abp5m1gp',
#   'NombreVotacion': 'DECRETO QUE ESTABLECE LAS CARACTERISTICAS DE UNA MONEDA CONMEMORATIVA DEL 150 ANIVERSARIO DE LA BATALLA DE PUEBLA DEL 5 DE MAYO DE 1862 (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '11 Abril 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'javiergilortiz': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'A favor',
#   'oralialopezhernandez': 'A favor'},
#  'aufxaa5ffaroscgp': {'ClaveUnicaVotacion': 'aufxaa5ffaroscgp',
#   'NombreVotacion': 'DECRETO QUE ADICIONA UNA FRACCION XIX AL ARTICULO 5 DE LA LEY FEDERAL DE FOMENTO A LAS ACTIVIDADES REALIZADAS POR LAS ORGANIZACIONES DE LA SOCIEDAD CIVIL (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '11 Abril 2012',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
# ...
#   'FechaVotacion': '30 Octubre 2009',
#   'javiergilortiz': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'Abstención',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'A favor',
#   'oralialopezhernandez': 'A favor'},
#  'radddliideicffeopduiraddcffsipd1a1pa6cr': {'ClaveUnicaVotacion': 'radddliideicffeopduiraddcffsipd1a1pa6cr',
#   'NombreVotacion': 'DECRETO QUE REFORMA, ADICIONA Y DEROGA DIVERSAS DISPOSICIONES DE LAS LEYES DEL ISR, DEL IMPUESTO A LOS DEPÓSITOS EN EFECTIVO, DEL IVA, DEL CÓDIGO FISCAL DE LA FEDERACIÓN Y DEL DECRETO POR EL QUE SE ESTABLECEN LAS OBLIGACIONES QUE PODRÁN DENOMINARSE EN UNIDADES DE INVERSIÓN; Y REFORMA Y ADICIONA DIVERSAS DISPOSICIONES DEL CÓDIGO FISCAL DE LA FEDERACIÓN Y DE LA LEY SOBRE EL ISR, PUBLICADO EN EL DOF EL 1 DE ABRIL DE 1995 (EN LO PARTICULAR EL ARTICULO 69 DEL CFF, RESERVADOS) ',
#   'FechaVotacion': '30 Octubre 2009',
#   'javiergilortiz': 'En contra',
#   'julianfranciscovelazquezyllorente': 'En contra',
#   'cristabellzamoracabrera': 'En contra',
#   'edgardomelhemsalinas': 'En contra',
#   'rodolfotorrecantu': 'En contra',
#   'baltazarmanuelhinojosaochoa': 'En contra',
#   'jesuseverardovillarrealsalinas': 'En contra',
#   'josefranciscorabagocastillo': 'En contra',
#   'luisalejandroguevaracobos': 'En contra',
#   'oralialopezhernandez': 'En contra'},
#  'raddiespspactr': {'ClaveUnicaVotacion': 'raddiespspactr',
#   'NombreVotacion': 'DECRETO QUE REFORMA Y ADICIONA DIVERSAS DISPOSICIONES DE LA LEY DEL IMPUESTO ESPECIAL SOBRE PRODUCCION Y SERVICIOS (EN LO PARTICULAR EL ARTICULO CUARTO TRANSITORIO RESERVADO) ',
#   'FechaVotacion': '30 Octubre 2009',
#   'javiergilortiz': 'En contra',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'En contra',
#   'edgardomelhemsalinas': 'En contra',
#   'rodolfotorrecantu': 'En contra',
#   'baltazarmanuelhinojosaochoa': 'En contra',
#   'jesuseverardovillarrealsalinas': 'En contra',
#   'josefranciscorabagocastillo': 'En contra',
#   'luisalejandroguevaracobos': 'En contra',
#   'oralialopezhernandez': 'En contra'},
#  'raddfdrarfppa2tr': {'ClaveUnicaVotacion': 'raddfdrarfppa2tr',
#   'NombreVotacion': 'DECRETO QUE REFORMA Y ADICIONA DIVERSAS DISPOSICIONES DE LA LEY FEDERAL DE DERECHOS RELATIVO AL REGIMEN FISCAL DE PEMEX (EN LO PARTICULAR EL ARTICULO 258 TER RESERVADO) ',
#   'FechaVotacion': '30 Octubre 2009',
#   'javiergilortiz': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'A favor',
#   'oralialopezhernandez': 'A favor'},
#  'lifef2pa71stapr': {'ClaveUnicaVotacion': 'lifef2pa71stapr',
#   'NombreVotacion': 'LEY DE INGRESOS DE LA FEDERACION PARA EL EJERCICIO FISCAL DE 2010 (EN LO PARTICULAR LOS ARTICULOS 7°, 17 Y SEGUNDO TRANSITORIO DEL ARTICULO PRIMERO RESERVADOS) ',
#   'FechaVotacion': '30 Octubre 2009',
#   'javiergilortiz': 'En contra',
#   'julianfranciscovelazquezyllorente': 'En contra',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'En contra',
#   'baltazarmanuelhinojosaochoa': 'En contra',
#   'jesuseverardovillarrealsalinas': 'Ausente',
#   'josefranciscorabagocastillo': 'En contra',
#   'luisalejandroguevaracobos': 'En contra',
#   'oralialopezhernandez': 'En contra'},
#  'cpapeumauclcgpbgp': {'ClaveUnicaVotacion': 'cpapeumauclcgpbgp',
#   'NombreVotacion': 'DECRETO QUE CONCEDE PERMISO AL PRESIDENTE DE LOS ESTADOS UNIDOS MEXICANOS PARA ACEPTAR Y USAR LA CONDECORACION QUE LE CONFIERE EL GOBIERNO DE LOS PAISES BAJOS (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '5 Noviembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'Ausente',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'Ausente',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'Ausente',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'cpcmzgcauclcgpbgp': {'ClaveUnicaVotacion': 'cpcmzgcauclcgpbgp',
#   'NombreVotacion': 'DECRETO QUE CONCEDE PERMISO A LA C. MARGARITA ZAVALA GOMEZ DEL CAMPO PARA ACEPTAR Y USAR LA CONDECORACION QUE LE CONFIERE EL GOBIERNO DE LOS PAISES BAJOS (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '5 Noviembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'Ausente',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'Ausente',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'aatctadra7ftpd1e2gpma': {'ClaveUnicaVotacion': 'aatctadra7ftpd1e2gpma',
#   'NombreVotacion': 'DECRETO POR EL QUE SE ADICIONA LOS ARTICULOS TERCERO Y CUARTO TRANSITORIOS AL DIVERSO QUE REFORMA EL ARTICULO 74 DE LA LEY FEDERAL DEL TRABAJO PUBLICADO EN EL DOF EL 17 DE ENERO DE 2006 (EN LO GENERAL Y EN LO PARTICULAR CON LA MODIFICACION ACEPTADA) ',
#   'FechaVotacion': '5 Noviembre 2009',
#   'javiergilortiz': 'A favor',
#   'julianfranciscovelazquezyllorente': 'Ausente',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'En contra',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'En contra',
#   'josefranciscorabagocastillo': 'En contra',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'Ausente'},
#  'dsucp3cmdcchscp6cmpsrgedcp2cmuclcgegp': {'ClaveUnicaVotacion': 'dsucp3cmdcchscp6cmpsrgedcp2cmuclcgegp',
#   'NombreVotacion': 'DIEZ DECRETOS, UNO QUE CONCEDE PERMISO A 3 CC MEXICANOS PARA DESEMPEÑAR CARGO DE CONSUL HONORARIO, SIETE QUE CONCEDEN PERMISO A 61 CC MEXICANOS PARA PRESTAR SERVICIOS EN REPRESENTACIONES DE GOBIERNOS EXTRANJEROS Y DOS QUE CONCEDEN PERMISO A 2 CC MEXICANOS PARA USAR CONDECORACIONES QUE LES CONFIEREN GOBIERNOS EXTRANJEROS (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '10 Noviembre 2009',
#   'javiergilortiz': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'cpaccejmpaumesggusdlcfarcgp': {'ClaveUnicaVotacion': 'cpaccejmpaumesggusdlcfarcgp',
#   'NombreVotacion': 'DECRETO QUE CONCEDE PERMISO AL C. CARLOS EDUARDO JIMENEZ MACOTELA PARA QUE PUEDA ACEPTAR Y USAR LA MEDALLA ESCUELA SUPERIOR DE GUERRA, EN GRADO UNICO DE SERVICIOS DISTINGUIDOS, QUE LE CONFIEREN LAS FUERZA ARMADAS DE LA REPÚBLICA DE COLOMBIA (EN LO GRAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '10 Noviembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'Ausente',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'jesuseverardovillarrealsalinas': 'Ausente',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'pefef2pa62t2a11178112313122222233rtd': {'ClaveUnicaVotacion': 'pefef2pa62t2a11178112313122222233rtd',
#   'NombreVotacion': 'PRESUPUESTO DE EGRESOS DE LA FEDERACION PARA EL EJERCICIO FISCAL 2010 (EN LO PARTICULAR LOS ARTICULOS 6, 29, TRANSITORIOS 23, ANEXOS 1B, 1C, 1D, 7, 8, 10, 16.2.3, 16.3.1, 24, 25, 26, 26E, 26G, 29, 30 Y 36 RESERVADOS, EN TERMINOS DEL DICTAMEN) ',
#   'FechaVotacion': '13 Noviembre 2009',
#   'javiergilortiz': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'pefef2pa33t2uta11122rmoaa': {'ClaveUnicaVotacion': 'pefef2pa33t2uta11122rmoaa',
#   'NombreVotacion': 'PRESUPUESTO DE EGRESOS DE LA FEDERACION PARA EL EJERCICIO FISCAL 2010 (EN LO PARTICULAR LOS ARTICULOS 36, 39, TRANSITORIOS 28 Y UN TRANSITORIO, ANEXOS 1, 12, 19, 22 Y 28 RESERVADOS, CON LAS MODIFICACIONES O ADICIONES ACEPTADAS) ',
#   'FechaVotacion': '13 Noviembre 2009',
#   'javiergilortiz': 'A favor',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'Abstención',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'papmdcdptfccasceeolscur': {'ClaveUnicaVotacion': 'papmdcdptfccasceeolscur',
#   'NombreVotacion': 'PUNTO DE ACUERDO PARA QUE EL PRESIDENTE DE LA MESA DIRECTIVA DE LA C.D., PRESENTE EN TIEMPO Y FORMA CONTROVERSIA CONSTITUCIONAL ANTE LA SCJN, EN CONTRA DEL DECRETO DEL EJECUTIVO QUE EXTINGUIO EL ORGANISMO LFC (SI SE CONSIDERA DE URGENTE RESOLUCION) ',
#   'FechaVotacion': '24 Noviembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'En contra',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'En contra',
#   'rodolfotorrecantu': 'En contra',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'En contra',
#   'josefranciscorabagocastillo': 'En contra',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'En contra'},
#  'ra7b17b1gsgp': {'ClaveUnicaVotacion': 'ra7b17b1gsgp',
#   'NombreVotacion': 'DECRETO QUE REFORMA LOS ARTICULOS 77 BIS 12 Y 77 BIS 13 DE LA LEY GENERAL DE SALUD (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '26 Noviembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'cscp1cmauclcge9cmpsregpanr': {'ClaveUnicaVotacion': 'cscp1cmauclcge9cmpsregpanr',
#   'NombreVotacion': 'CINCO DECRETOS QUE CONCEDEN PERMISO A 14 CIUDADANOS MEXICANOS PARA ACEPTAR Y USAR CONDECORACIONES QUE LES CONFIEREN GOBIERNOS EXTRANJEROS Y A 9 CIUDADANOS MEXICANOS PARA PRESTAR SERVICIOS EN REPRESENTACIONES EXTRANJERAS (EN LO GENERAL Y EN LO PARTICULAR LOS ARTICULOS NO RESERVADOS) ',
#   'FechaVotacion': '10 Diciembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'cp1cmauclcgepac': {'ClaveUnicaVotacion': 'cp1cmauclcgepac',
#   'NombreVotacion': 'DECRETO QUE CONCEDE PERMISO A 13 CIUDADANOS MEXICANOS PARA ACEPTAR Y USAR CONDECORACIONES QUE LES CONFIEREN GOBIERNOS EXTRANJEROS (EN LO PARTICULAR EL ARTICULO CUARTO) ',
#   'FechaVotacion': '10 Diciembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'rfia3sheumgp': {'ClaveUnicaVotacion': 'rfia3sheumgp',
#   'NombreVotacion': 'DECRETO QUE REFORMA LA FRACCION II DEL ARTICULO 3° DE LA LEY DEL SISTEMA DE HORARIO DE LOS ESTADOS UNIDOS MEXICANOS (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '10 Diciembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'aupaaueheaeumgpma': {'ClaveUnicaVotacion': 'aupaaueheaeumgpma',
#   'NombreVotacion': 'DECRETO QUE ADICIONA UN PARRAFO AL ARTICULO UNICO DEL DECRETO POR EL QUE SE ESTABLECE EL HORARIO ESTACIONAL, QUE APLICARA EN LOS ESTADOS UNIDOS MEXICANOS (EN LO GENERAL Y EN LO PARTICULAR, CON LA MODIFICACION ACEPTADA) ',
#   'FechaVotacion': '10 Diciembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'A favor',
#   'cristabellzamoracabrera': 'A favor',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'Ausente',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'Ausente',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'},
#  'radddliiiceopduraddcipd0a1pd0d2gpma': {'ClaveUnicaVotacion': 'radddliiiceopduraddcipd0a1pd0d2gpma',
#   'NombreVotacion': 'DECRETO POR EL QUE SE REFORMAN, ADICIONAN Y DEROGAN DIVERSAS DISPOSICIONES DE LAS LEYES DEL ISR, IDE, IVA, CFF, Y DEL DECRETO POR EL QUE SE ESTABLECEN LAS OBLIGACIONES QUE PODRAN DENOMINARSE EN UDIS Y REFORMA Y ADICIONA DIVERSAS DISP. DEL CFF Y DE LA LEY DEL ISR PUBLICADO EN EL DOF EL 01 DE ABRIL DE 1995 Y PUBLICADO EN EL DOF EL 07 DE DICIEMBRE 2009 (EN LO GENERAL Y EN LO PARTICULAR, CON LA MODIFICACION ACEPTADA) ',
#   'FechaVotacion': '15 Diciembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'Ausente',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'A favor',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'jesuseverardovillarrealsalinas': 'A favor',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'A favor',
#   'oralialopezhernandez': 'A favor'},
#  'maddaerftema3bspeegp': {'ClaveUnicaVotacion': 'maddaerftema3bspeegp',
#   'NombreVotacion': 'DECRETO QUE MODIFICA Y ADICIONA DIVERSAS DISPOSICIONES DE LA LEY PARA EL APROVECHAMIENTO DE ENERGIAS RENOVABLES Y EL FINANCIAMIENTO DE LA TRANSICION ENERGETICA, Y MODIFICA EL ARTICULO 36 BIS DE LA LEY DEL SERVICIO PUBLICO DE ENERGIA ELECTRICA (EN LO GENERAL Y EN LO PARTICULAR) ',
#   'FechaVotacion': '15 Diciembre 2009',
#   'javiergilortiz': 'Ausente',
#   'julianfranciscovelazquezyllorente': 'Ausente',
#   'cristabellzamoracabrera': 'Ausente',
#   'edgardomelhemsalinas': 'Ausente',
#   'rodolfotorrecantu': 'A favor',
#   'baltazarmanuelhinojosaochoa': 'A favor',
#   'jesuseverardovillarrealsalinas': 'Ausente',
#   'josefranciscorabagocastillo': 'A favor',
#   'luisalejandroguevaracobos': 'Ausente',
#   'oralialopezhernandez': 'A favor'}}
